# %%
import pandas as pd
import numpy as np
import seaborn as sns
data = pd.read_excel("D:\MCA-4th semester\data science dataset\Student info.xlsx")
print(data)
# Out:
#         Reg no                  name blood group      dept  subject 1  \
# 0   2019272001                abarna          b+       ist         78
# 1   2019272002  abhijeet chakarvorty          b+       CSE         87
# 2   2019272003                  aman          o+       EEE         78
# 3   2019272004           anjan kumar          b+       ECE         71
# 4   2019272005                  arun          a+      mech         77
# 5   2019272006          balaji prame          b+      mech         70
# 6   2019272007          DINESH KUMAR          b+      mech         77
# 7   2019272008              DHIVAGAR          b+      mech         78
# 8   2019272009          HARI VISWESH          b+      mech         80
# 9   2019272010             HARIHARAN          b+      mech         88
# 10  2019272011              HARITHHA          o+       ist         81
# 11  2019272012              JAYASREE          o+       ist         78
# ...

# %%
data.head()
# Out:
#        Reg no                  name blood group  dept  subject 1  subject 2  \
# 0  2019272001                abarna          b+   ist         78         77
# 1  2019272002  abhijeet chakarvorty          b+   CSE         87         77
# 2  2019272003                  aman          o+   EEE         78         67
# 3  2019272004           anjan kumar          b+   ECE         71         81
# 4  2019272005                  arun          a+  mech         77         78
#
#    subject 3  subject 4 subject 5 subject 5.1  phone number
# 0         76         79        77          89    9756789345
# 1         78         89        90          92    8891456782
# 2         70         77        71          78    9789867891
# 3         88         77        78          87    8176543281
# 4         71         66        67          70    8765903452

# %%
data.tail(10)
# Out:
#         Reg no                name blood group      dept  subject 1  \
# 28  2019272033      SAMUNDAR SINGH          o+       ist         77
# 29  2019272034            SANDHIYA          O+       ist         77
# 30  2019272035             SATHISH          o+       ist         89
# 31  2019272036   SHANKAR NARAYANAN          b+       ist         56
# 32  2019272037         SRI LAKSHMI          b+       ist         56
# 33  2019272038             SURYA R          b+       ist         78
# 34  2019272039             SURYA S          b-       ist         56
# 35  2019272040        VIGNESHWARAN          o+       ist         78
# 36  2019272041  VISHAL KUMAR SINGH          o+       ECE         78
# 37  2019272043     YASHIKA LAKSHMI          o+  chemical         67
#
#     subject 2  subject 3  subject 4 subject 5                   subject 5.1  \
# 28         67         89         77        78                            67
# ...

# %%
data.shape
# Out:
# (38, 11)

# %%
data['subject 3'].describe()
# Out:
# count    38.000000
# mean     74.368421
# std       7.386698
# min      57.000000
# 25%      70.000000
# 50%      76.500000
# 75%      78.000000
# max      89.000000
# Name: subject 3, dtype: float64

# %%
data.columns
# Out:
# Index(['Reg no', 'name', 'blood group', 'dept', 'subject 1', 'subject 2',
#        'subject 3', 'subject 4', 'subject 5', 'subject 5.1', 'phone number'],
#       dtype='object')

# %%
data.nunique()
# Out:
# Reg no          38
# name            38
# blood group      8
# dept             6
# subject 1       13
# subject 2        9
# subject 3       14
# subject 4       14
# subject 5       16
# subject 5.1     17
# phone number    38
# dtype: int64

# %%
data['dept'].nunique()
# Out:
# 6

# %%
data.isnull()
# Out:
#     Reg no   name  blood group   dept  subject 1  subject 2  subject 3  \
# 0    False  False        False  False      False      False      False
# 1    False  False        False  False      False      False      False
# 2    False  False        False  False      False      False      False
# 3    False  False        False  False      False      False      False
# 4    False  False        False  False      False      False      False
# 5    False  False        False  False      False      False      False
# 6    False  False        False  False      False      False      False
# 7    False  False        False  False      False      False      False
# 8    False  False        False  False      False      False      False
# 9    False  False        False  False      False      False      False
# 10   False  False        False  False      False      False      False
# 11   False  False        False  False      False      False      False
# ...

# %%
data.isnull().sum()
# Out:
# Reg no          0
# name            0
# blood group     0
# dept            0
# subject 1       0
# subject 2       0
# subject 3       0
# subject 4       0
# subject 5       0
# subject 5.1     0
# phone number    0
# dtype: int64

# %%
 student = data.drop(['subject 5.1'],axis=1)

# %%
student.head()
# Out:
#        Reg no                  name blood group  dept  subject 1  subject 2  \
# 0  2019272001                abarna          b+   ist         78         77
# 1  2019272002  abhijeet chakarvorty          b+   CSE         87         77
# 2  2019272003                  aman          o+   EEE         78         67
# 3  2019272004           anjan kumar          b+   ECE         71         81
# 4  2019272005                  arun          a+  mech         77         78
#
#    subject 3  subject 4 subject 5  phone number
# 0         76         79        77    9756789345
# 1         78         89        90    8891456782
# 2         70         77        71    9789867891
# 3         88         77        78    8176543281
# 4         71         66        67    8765903452

# %%
# 3 relationship analysis

# %%
correlation = student.corr()

# %%
sns.heatmap(correlation, xticklabels=True, yticklabels=True, annot=True)
# Out:
# <AxesSubplot:>

# %%
#visulaization parts

# %%
sns.pairplot(student)

# %%
sns.relplot(x='subject 1', y='subject 3', hue='dept', data=student)

# %%
sns.distplot(student['subject 1'], bins=5)
# Out:
# c:\users\karthika\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='subject 1', ylabel='Density'>

# %%
sns.catplot(x='subject 3', kind='box', data=student)

# %%
sns.countplot(x='subject 2', hue='dept', data=student)
# Out:
# <AxesSubplot:xlabel='subject 2', ylabel='count'>
